# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/goodreads-books/cleaned_description.csv
# /kaggle/input/goodreads-books/cleaned_books.csv.bz2
# /kaggle/input/goodreads-books/full_df.csv.bz2

# %% [markdown]
# ## Data Science Problem

# %% [markdown]
# Goodreads is a popular online platform where readers can discover new books, read reviews, and connect with other readers. However, with millions of books available on the platform, it can be overwhelming for users to find books that match their preferences. In this project, we aim to build a recommendation system for Goodreads users that suggests books based on their reading history, preferences, and ratings. Our goal is to provide a personalized and intuitive experience for users, helping them discover new books that they are likely to enjoy. Using supervised learning and NLP techniques, we will build a model that can predict the likelihood of a user liking a book based on features such as book title, author, genre, description, user reviews, and book ratings. The model will be trained on a subset of the Goodreads dataset and evaluated based on accuracy, precision, recall, and F1-score. The final output will be a recommendation engine that suggests books to users based on their input and history on the platform.

# %% [markdown]
# Data Extracted from UCSD Goodreads data: https://sites.google.com/eng.ucsd.edu/ucsdbookgraph/home

# %% [markdown]
# ## Objectives

# %% [markdown]
# In the preprocessing step, we aim to clean and transform the raw data into a format that is suitable for machine learning models.
# Here are some of the questions we aim to answer during the preprocessing step in this notebook:
#
# Data Cleaning:
# Are there any missing values in the dataset?
# Are there any duplicate entries in the dataset?
# Are there any irrelevant features in the dataset that can be removed?
# Are there any inconsistencies in the data that need to be corrected?
#
# Data Transformation:
# How can we extract relevant features from the dataset, such as book title, author, genre, description, user reviews, and book ratings?
# How can we preprocess the text data to make it suitable for machine learning models, such as tokenization, removing stop words, stemming, and lemmatization?
# How can we convert the text data into numerical features that can be used in machine learning models, such as TF-IDF, Bag of Words, or Word2Vec?
#
# Exploratory Data Analysis:
# What is the distribution of ratings in the dataset?
# What are the most popular genres and authors in the dataset?
# Are there any correlations between different features in the dataset?
#
# Data Preparation:
# How can we split the dataset into training and testing sets?
# How can we balance the dataset to handle class imbalance?
# How can we encode categorical variables into numerical variables?
#
# Answering these questions during the preprocessing step is crucial in building an accurate and robust recommendation system that can provide personalized recommendations to Goodreads users.

# %%
df = pd.read_csv('/kaggle/input/goodreads-books/full_df.csv.bz2', compression='bz2')

# %%
df.shape
# Out:
# (1115445, 16)

# %%
df.head()
# Out:
#    book_id        isbn  author_id           authors  \
# 0  1333909  0743509986     626222     Anita Diamant
# 1  7327624         NaN      10333    Barbara Hambly
# 2  6066819  0743294297       9212   Jennifer Weiner
# 3   287141  1599150603    3041852  Alfred J. Church
# 4  6066812  1934876569      19158    Rachel Roberts
#
#                                                title  \
# 0                                        Good Harbor
# 1  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 2                               Best Friends Forever
# 3                      The Aeneid for Boys and Girls
# 4  All's Fairy in Love and War (Avalon: Web of Ma...
#
#                                          description               publisher  \
# 0  Anita Diamant's international bestseller "The ...  Simon & Schuster Audio
# 1  Omnibus book club edition containing the Ladie...  Nelson Doubleday, Inc.
# 2  Addie Downs and Valerie Adler were eight when ...             Atria Books
# 3  Relates in vigorous prose the tale of Aeneas, ...    Yesterday's Classics
# 4  To Kara's astonishment, she discovers that a p...              Seven Seas
#
#                                               genres  avg_rating  \
# 0  ['to-read', 'fiction', 'currently-reading', 'c...        3.23
# 1  ['to-read', 'fantasy', 'fiction', 'owned', 'ha...        4.03
# 2  ['to-read', 'chick-lit', 'currently-reading', ...        3.49
# 3  ['to-read', 'currently-reading', 'history', 'c...        4.13
# 4  ['to-read', 'fantasy', 'owned', 'books-i-own',...        4.22
#
#    ratings_count  num_pages  pub_year language_code  \
# 0             10          0    2001.0           NaN
# 1            140        600    1987.0           eng
# 2          51184        368    2009.0           eng
# 3             46        162    2006.0           NaN
# 4             98        216    2009.0           NaN
#
#                                        similar_books  \
# 0  ['8709549', '17074050', '28937', '158816', '22...
# 1  ['19997', '828466', '1569323', '425389', '1176...
# 2  ['6604176', '6054190', '2285777', '82641', '75...
# 3                                                 []
# 4  ['948696', '439885', '274955', '12978730', '37...
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/1333909.Go...
# 1  https://www.goodreads.com/book/show/7327624-th...
# 2  https://www.goodreads.com/book/show/6066819-be...
# 3  https://www.goodreads.com/book/show/287141.The...
# 4  https://www.goodreads.com/book/show/6066812-al...
#
#                                          cover_image
# 0  https://s.gr-assets.com/assets/nophoto/book/11...
# 1  https://images.gr-assets.com/books/1304100136m...
# 2  https://s.gr-assets.com/assets/nophoto/book/11...
# 3  https://s.gr-assets.com/assets/nophoto/book/11...
# 4  https://images.gr-assets.com/books/1316637798m...

# %%
df.columns
# Out:
# Index(['book_id', 'isbn', 'author_id', 'authors', 'title', 'description',
#        'publisher', 'genres', 'avg_rating', 'ratings_count', 'num_pages',
#        'pub_year', 'language_code', 'similar_books', 'url', 'cover_image'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115445 entries, 0 to 1115444
# Data columns (total 16 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   book_id        1115445 non-null  int64
#  1   isbn           760981 non-null   object
#  2   author_id      1115445 non-null  int64
#  3   authors        1115444 non-null  object
#  4   title          1115442 non-null  object
#  5   description    1115435 non-null  object
#  6   publisher      863332 non-null   object
#  7   genres         1115445 non-null  object
#  8   avg_rating     1115445 non-null  float64
#  9   ratings_count  1115445 non-null  int64
#  10  num_pages      1115445 non-null  int64
#  11  pub_year       896977 non-null   float64
#  12  language_code  522531 non-null   object
#  13  similar_books  1115445 non-null  object
#  14  url            1115445 non-null  object
#  15  cover_image    1115445 non-null  object
# dtypes: float64(2), int64(4), object(10)
# memory usage: 136.2+ MB

# %% [markdown]
# ## Number Of Missing Values By Column

# %%
missing = pd.concat([df.isna().sum(), 100* df.isna().mean()], axis = 1)
missing.columns = ['count','%']
missing.sort_values(by = 'count')
# Out:
#                 count          %
# book_id             0   0.000000
# author_id           0   0.000000
# genres              0   0.000000
# avg_rating          0   0.000000
# ratings_count       0   0.000000
# num_pages           0   0.000000
# similar_books       0   0.000000
# url                 0   0.000000
# cover_image         0   0.000000
# authors             1   0.000090
# title               3   0.000269
# description        10   0.000897
# pub_year       218468  19.585726
# publisher      252113  22.602011
# isbn           354464  31.777811
# language_code  592914  53.154929

# %%
# Let's look closely at the "language code" and "isbn" coloums
df['language_code'].value_counts()
# Out:
# eng    522531
# Name: language_code, dtype: int64

# %%
df['language_code'].isna().sum()
# Out:
# 592914

# %%
#Removing the language code columns: There are 50% missing value in "language code coloumn". We saw that the only langauge represented in this column is Engish, so, it does not provide any insights for the recommender system.
df = df.drop('language_code', axis = 1)

# %%
df = df.drop('isbn', axis =1)

# %% [markdown]
# ## Categorical Features

# %%
df.select_dtypes('object')
# Out:
#                     authors  \
# 0             Anita Diamant
# 1            Barbara Hambly
# 2           Jennifer Weiner
# 3          Alfred J. Church
# 4            Rachel Roberts
# ...                     ...
# 1115440         Trish Morey
# 1115441     Christopher Lee
# 1115442  Arthur Conan Doyle
# 1115443       Nicola Baxter
# 1115444          S.E. Reign
#
#                                                      title  \
# 0                                              Good Harbor
# 1        The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 2                                     Best Friends Forever
# 3                            The Aeneid for Boys and Girls
# 4        All's Fairy in Love and War (Avalon: Web of Ma...
# ...                                                    ...
# 1115440                   The Spaniard's Blackmailed Bride
# 1115441  This Sceptred Isle, Vol. 10: The Age of Victor...
# 1115442                Sherlock Holmes and the July Crisis
# 1115443           The Children's Classic Poetry Collection
# 1115444          101 Nights: Volume One (101 Nights, #1-3)
#
#                                                description  \
# 0        Anita Diamant's international bestseller "The ...
# 1        Omnibus book club edition containing the Ladie...
# 2        Addie Downs and Valerie Adler were eight when ...
# 3        Relates in vigorous prose the tale of Aeneas, ...
# 4        To Kara's astonishment, she discovers that a p...
# ...                                                    ...
# 1115440  Blackmailed into marriage to save her family, ...
# 1115441  The award-winning story of Britain, from the a...
# 1115442  Sir Arthur Conan Doyle is brought back to life...
# 1115443  Gathers poems by William Blake, Emily Bronte, ...
# 1115444  Volume One contains: "Claimed," "Tainted," and...
#
#                       publisher  \
# 0        Simon & Schuster Audio
# 1        Nelson Doubleday, Inc.
# 2                   Atria Books
# 3          Yesterday's Classics
# 4                    Seven Seas
# ...                         ...
# 1115440               Harlequin
# 1115441          BBC Audiobooks
# 1115442           MX Publishing
# 1115443    Smithmark Publishers
# 1115444      Guerrilla Wordfare
#
#                                                     genres  \
# 0        ['to-read', 'fiction', 'currently-reading', 'c...
# 1        ['to-read', 'fantasy', 'fiction', 'owned', 'ha...
# 2        ['to-read', 'chick-lit', 'currently-reading', ...
# 3        ['to-read', 'currently-reading', 'history', 'c...
# 4        ['to-read', 'fantasy', 'owned', 'books-i-own',...
# ...                                                    ...
# 1115440  ['to-read', 'harlequin', 'harlequin-presents',...
# 1115441  ['to-read', 'non-fiction', 'audiobooks', 'hist...
# 1115442  ['to-read', 'mystery', 'giveaways', 'baker-str...
# 1115443  ['to-read', 'poetry', 'default', 'currently-re...
# 1115444  ['to-read', 'erotica', 'kindle', 'romance', 's...
#
#                                              similar_books  \
# 0        ['8709549', '17074050', '28937', '158816', '22...
# 1        ['19997', '828466', '1569323', '425389', '1176...
# 2        ['6604176', '6054190', '2285777', '82641', '75...
# 3                                                       []
# 4        ['948696', '439885', '274955', '12978730', '37...
# ...                                                    ...
# 1115440  ['2200344', '695337', '10333421', '1934240', '...
# 1115441                                                 []
# 1115442  ['12064253', '25017213', '571796', '27306126',...
# 1115443                                                 []
# 1115444  ['23562786', '13548289', '26094541', '20570173...
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/1333909.Go...
# 1        https://www.goodreads.com/book/show/7327624-th...
# 2        https://www.goodreads.com/book/show/6066819-be...
# 3        https://www.goodreads.com/book/show/287141.The...
# 4        https://www.goodreads.com/book/show/6066812-al...
# ...                                                    ...
# 1115440  https://www.goodreads.com/book/show/2685097-th...
# 1115441  https://www.goodreads.com/book/show/3084038-th...
# 1115442  https://www.goodreads.com/book/show/26168430-s...
# 1115443  https://www.goodreads.com/book/show/2342551.Th...
# 1115444  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image
# 0        https://s.gr-assets.com/assets/nophoto/book/11...
# 1        https://images.gr-assets.com/books/1304100136m...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://s.gr-assets.com/assets/nophoto/book/11...
# 4        https://images.gr-assets.com/books/1316637798m...
# ...                                                    ...
# 1115440  https://s.gr-assets.com/assets/nophoto/book/11...
# 1115441  https://images.gr-assets.com/books/1494763458m...
# 1115442  https://images.gr-assets.com/books/1440592011m...
# 1115443  https://s.gr-assets.com/assets/nophoto/book/11...
# 1115444  https://images.gr-assets.com/books/1398621236m...
#
# [1115445 rows x 8 columns]

# %%
df = df.drop('cover_image', axis =1)

# %%
df['book_id'].value_counts().sum()
# Out:
# 1115445

# %%
df['author_id'].value_counts().head()
# Out:
# 123715     1988
# 3780       1762
# 3389       1516
# 5158478    1275
# 947        1271
# Name: author_id, dtype: int64

# %%
df['title'].value_counts().head()
# Out:
# Pride and Prejudice    246
# Jane Eyre              221
# Wuthering Heights      205
# Selected Poems         183
# Dracula                183
# Name: title, dtype: int64

# %%
df[['title','authors']].nunique()
# Out:
# title      818982
# authors    271339
# dtype: int64

# %%
(df['title'] + ', ' + df['authors']).value_counts().head()
# Out:
# Pride and Prejudice, Jane Austen             238
# Jane Eyre, Charlotte Bronte                  216
# Wuthering Heights, Emily Bronte              200
# Dracula, Bram Stoker                         167
# Frankenstein, Mary Wollstonecraft Shelley    152
# dtype: int64

# %%
df[df[['title', 'authors']].duplicated()]
# Out:
#           book_id  author_id            authors  \
# 351        820229       7128       Jodi Picoult
# 356        820227       7128       Jodi Picoult
# 483      35593693     822613    Pierre Lemaitre
# 511       8037412       3420  Elizabeth Enright
# 619      25580382       5194   Michael Crichton
# ...           ...        ...                ...
# 1115412  24784578    5234671      S.M. Blooding
# 1115418   7925060    1221698        Neil Gaiman
# 1115425  25308738   13786119        Alan Joshua
# 1115427   7195902       1455   Ernest Hemingway
# 1115429  23636536      11664     David Levithan
#
#                                             title  \
# 351                                 Second Glance
# 356                                 Second Glance
# 483                         Three Days and a Life
# 511                                 The Saturdays
# 619             Jurassic Park (Jurassic Park, #1)
# ...                                           ...
# 1115412       Whiskey Witches - Complete Season 1
# 1115418                              Instructions
# 1115425                        The SHIVA Syndrome
# 1115427  The Short Happy Life of Francis Macomber
# 1115429                               Another Day
#
#                                                description  \
# 351      From the moment Ross's fiancee Aimee was kille...
# 356      From the moment Ross's fiancee Aimee was kille...
# 483      "In 1999, in the small provincial town of Beau...
# 511      Saturdays can make dreams come true when the M...
# 619      This is an alternate cover edition for ISBN ....
# ...                                                    ...
# 1115412  Detective Paige Whiskey comes from a long line...
# 1115418  "A perfect reminder to always be on the lookou...
# 1115425  Goodreads Readers:\n"The Shiva Syndrome is in ...
# 1115427  "The Short Happy Life of Francis Macomber" is ...
# 1115429  The eagerly anticipated companion to David Lev...
#
#                              publisher  \
# 351                                NaN
# 356                             Hodder
# 483            Maclehose Press Quercus
# 511                                NaN
# 619                   Ballantine Books
# ...                                ...
# 1115412                            NaN
# 1115418                  HarperCollins
# 1115425                            NaN
# 1115427                            NaN
# 1115429  Knopf Books for Young Readers
#
#                                                     genres  avg_rating  \
# 351      ['to-read', 'currently-reading', 'fiction', 'j...        3.79
# 356      ['to-read', 'currently-reading', 'fiction', 'j...        3.79
# 483      ['to-read', 'thriller', 'french', 'suspense', ...        3.57
# 511      ['to-read', 'childrens', 'fiction', 'children'...        4.14
# 619      ['to-read', 'science-fiction', 'fiction', 'sci...        3.97
# ...                                                    ...         ...
# 1115412  ['to-read', 'currently-reading', 'kindle', 'fa...        3.96
# 1115418  ['to-read', 'fantasy', 'picture-books', 'child...        4.29
# 1115425  ['to-read', 'paranormal', 'netgalley', 'to-rev...        4.32
# 1115427  ['to-read', 'short-stories', 'fiction', 'class...        4.07
# 1115429  ['to-read', 'currently-reading', 'young-adult'...        3.67
#
#          ratings_count  num_pages  pub_year  \
# 351                 82          0       NaN
# 356                 24        420    2007.0
# 483                 50          0    2017.0
# 511                  6          0       NaN
# 619                294        448    2015.0
# ...                ...        ...       ...
# 1115412            127          0       NaN
# 1115418             40         40    2010.0
# 1115425             31        526       NaN
# 1115427            290          0       NaN
# 1115429             29        336    2015.0
#
#                                              similar_books  \
# 351      ['8359929', '723742', '297130', '7570244', '39...
# 356      ['8359929', '723742', '297130', '7570244', '39...
# 483      ['6650065', '394154', '12398221', '232396', '4...
# 511      ['7926', '42337', '7904', '7932', '377889', '3...
# 619      ['117710', '19691', '136641', '611637', '35449...
# ...                                                    ...
# 1115412  ['13505327', '1752135', '12591482', '18770492'...
# 1115418  ['7552359', '7493149', '9762805', '8409657', '...
# 1115425  ['27391087', '25253442', '23441596', '28182084...
# 1115427  ['978053', '425481', '361551', '255045', '2581...
# 1115429  ['26802671', '20662291', '23615716', '23870836...
#
#                                                        url
# 351      https://www.goodreads.com/book/show/820229.Sec...
# 356      https://www.goodreads.com/book/show/820227.Sec...
# 483      https://www.goodreads.com/book/show/35593693-t...
# 511      https://www.goodreads.com/book/show/8037412-th...
# 619      https://www.goodreads.com/book/show/25580382-j...
# ...                                                    ...
# 1115412  https://www.goodreads.com/book/show/24784578-w...
# 1115418  https://www.goodreads.com/book/show/7925060-in...
# 1115425  https://www.goodreads.com/book/show/25308738-t...
# 1115427  https://www.goodreads.com/book/show/7195902-th...
# 1115429  https://www.goodreads.com/book/show/23636536-a...
#
# [245814 rows x 13 columns]

# %%
df.duplicated(subset=['title','authors']).value_counts()
# Out:
# False    869631
# True     245814
# dtype: int64

# %%
df[df['title']=='Second Glance']
# Out:
#          book_id  author_id       authors          title  \
# 350       820228       7128  Jodi Picoult  Second Glance
# 351       820229       7128  Jodi Picoult  Second Glance
# 356       820227       7128  Jodi Picoult  Second Glance
# 113311   6397205       7128  Jodi Picoult  Second Glance
# 175578     10911       7128  Jodi Picoult  Second Glance
# 451391   2355102       7128  Jodi Picoult  Second Glance
# 512842  11214862       7128  Jodi Picoult  Second Glance
# 630403    526465       7128  Jodi Picoult  Second Glance
# 665498   3104040       7128  Jodi Picoult  Second Glance
#
#                                               description  \
# 350     Ross, a suicidal drifter and ghost hunter, is ...
# 351     From the moment Ross's fiancee Aimee was kille...
# 356     From the moment Ross's fiancee Aimee was kille...
# 113311  From the moment Ross's fiancee Aimee was kille...
# 175578  When odd, supernatural events plague the town ...
# 451391  - From the New York Times best-selling author ...
# 512842  From the moment Ross's fiancee Aimee was kille...
# 630403  "Sometimes I wonder....Can a ghost find you, i...
# 665498  "Sometimes I wonder....Can a ghost find you, i...
#
#                       publisher  \
# 350                         NaN
# 351                         NaN
# 356                      Hodder
# 113311              Atria Books
# 175578                      NaN
# 451391           Recorded Books
# 512842                      NaN
# 630403              Atria Books
# 665498  Washington Square Press
#
#                                                    genres  avg_rating  \
# 350     ['to-read', 'currently-reading', 'fiction', 'j...        3.79
# 351     ['to-read', 'currently-reading', 'fiction', 'j...        3.79
# 356     ['to-read', 'currently-reading', 'fiction', 'j...        3.79
# 113311  ['to-read', 'currently-reading', 'fiction', 'j...        3.79
# 175578  ['to-read', 'currently-reading', 'fiction', 'j...        3.79
# 451391  ['to-read', 'currently-reading', 'fiction', 'j...        3.79
# 512842  ['to-read', 'currently-reading', 'fiction', 'j...        3.79
# 630403  ['to-read', 'currently-reading', 'fiction', 'j...        3.79
# 665498  ['to-read', 'currently-reading', 'fiction', 'j...        3.79
#
#         ratings_count  num_pages  pub_year  \
# 350                70          0    2006.0
# 351                82          0       NaN
# 356                24        420    2007.0
# 113311           1200        494    2003.0
# 175578          33808          0       NaN
# 451391             22          0    2008.0
# 512842             32          0       NaN
# 630403            157        432    2003.0
# 665498            928        420    2008.0
#
#                                             similar_books  \
# 350     ['8359929', '723742', '297130', '7570244', '39...
# 351     ['8359929', '723742', '297130', '7570244', '39...
# 356     ['8359929', '723742', '297130', '7570244', '39...
# 113311  ['8359929', '723742', '297130', '7570244', '39...
# 175578  ['8359929', '723742', '297130', '7570244', '39...
# 451391  ['8359929', '723742', '297130', '7570244', '39...
# 512842  ['8359929', '723742', '297130', '7570244', '39...
# 630403  ['8359929', '723742', '297130', '7570244', '39...
# 665498  ['8359929', '723742', '297130', '7570244', '39...
#
#                                                       url
# 350     https://www.goodreads.com/book/show/820228.Sec...
# 351     https://www.goodreads.com/book/show/820229.Sec...
# 356     https://www.goodreads.com/book/show/820227.Sec...
# 113311  https://www.goodreads.com/book/show/6397205-se...
# 175578  https://www.goodreads.com/book/show/10911.Seco...
# 451391  https://www.goodreads.com/book/show/2355102.Se...
# 512842  https://www.goodreads.com/book/show/11214862-s...
# 630403  https://www.goodreads.com/book/show/526465.Sec...
# 665498  https://www.goodreads.com/book/show/3104040-se...

# %%
df[df['title']=='Three Days and a Life']
# Out:
#           book_id  author_id          authors                  title  \
# 482      35593692     822613  Pierre Lemaitre  Three Days and a Life
# 483      35593693     822613  Pierre Lemaitre  Three Days and a Life
# 800570   34974147     822613  Pierre Lemaitre  Three Days and a Life
# 1004886  32941442     822613  Pierre Lemaitre  Three Days and a Life
# 1062714  35849902     822613  Pierre Lemaitre  Three Days and a Life
#
#                                                description  \
# 482      "In 1999, in the small provincial town of Beau...
# 483      "In 1999, in the small provincial town of Beau...
# 800570   In 1999, in the small provincial town of Beauv...
# 1004886  Three days at the edge of the new millennium, ...
# 1062714  "In 1999, in the small provincial town of Beau...
#
#                        publisher  \
# 482      Maclehose Press Quercus
# 483      Maclehose Press Quercus
# 800570                       NaN
# 1004886          MacLehose Press
# 1062714                      NaN
#
#                                                     genres  avg_rating  \
# 482      ['to-read', 'thriller', 'french', 'suspense', ...        3.57
# 483      ['to-read', 'thriller', 'french', 'suspense', ...        3.57
# 800570   ['to-read', 'thriller', 'french', 'suspense', ...        3.57
# 1004886  ['to-read', 'thriller', 'french', 'suspense', ...        3.57
# 1062714  ['to-read', 'thriller', 'french', 'suspense', ...        3.57
#
#          ratings_count  num_pages  pub_year  \
# 482                 15          0    2017.0
# 483                 50          0    2017.0
# 800570              14          0       NaN
# 1004886             19        320    2017.0
# 1062714              8          0       NaN
#
#                                              similar_books  \
# 482      ['6650065', '394154', '12398221', '232396', '4...
# 483      ['6650065', '394154', '12398221', '232396', '4...
# 800570   ['6650065', '394154', '12398221', '232396', '4...
# 1004886  ['6650065', '394154', '12398221', '232396', '4...
# 1062714  ['6650065', '394154', '12398221', '232396', '4...
#
#                                                        url
# 482      https://www.goodreads.com/book/show/35593692-t...
# 483      https://www.goodreads.com/book/show/35593693-t...
# 800570   https://www.goodreads.com/book/show/34974147-t...
# 1004886  https://www.goodreads.com/book/show/32941442-t...
# 1062714  https://www.goodreads.com/book/show/35849902-t...

# %%
 len(df['authors'].unique())
# Out:
# 271340

# %%
len(df['title'].unique())
# Out:
# 818983

# %% [markdown]
# ## Imputing the NAN values and Removing the duplicates

# %%
from sklearn.impute import SimpleImputer

# %%
# create the imputer object with most_frequent strategy
imputer = SimpleImputer(strategy = 'most_frequent')
# fit the imputer to the data
imputer.fit(df)
# impute missing values in each column
data_imputed = imputer.transform(df)

# convert the imputed data back to a pandas dataframe
data_imputed_df = pd.DataFrame(data_imputed, columns=df.columns)

# print the first 5 rows of the imputed dataframe
print(data_imputed_df.head())
# Out:
#    book_id author_id           authors  \
# 0  1333909    626222     Anita Diamant
# 1  7327624     10333    Barbara Hambly
# 2  6066819      9212   Jennifer Weiner
# 3   287141   3041852  Alfred J. Church
# 4  6066812     19158    Rachel Roberts
#
#                                                title  \
# 0                                        Good Harbor
# 1  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 2                               Best Friends Forever
# 3                      The Aeneid for Boys and Girls
# 4  All's Fairy in Love and War (Avalon: Web of Ma...
#
#                                          description               publisher  \
# 0  Anita Diamant's international bestseller "The ...  Simon & Schuster Audio
# 1  Omnibus book club edition containing the Ladie...  Nelson Doubleday, Inc.
# 2  Addie Downs and Valerie Adler were eight when ...             Atria Books
# 3  Relates in vigorous prose the tale of Aeneas, ...    Yesterday's Classics
# 4  To Kara's astonishment, she discovers that a p...              Seven Seas
#
#                                               genres avg_rating ratings_count  \
# 0  ['to-read', 'fiction', 'currently-reading', 'c...       3.23            10
# 1  ['to-read', 'fantasy', 'fiction', 'owned', 'ha...       4.03           140
# 2  ['to-read', 'chick-lit', 'currently-reading', ...       3.49         51184
# 3  ['to-read', 'currently-reading', 'history', 'c...       4.13            46
# 4  ['to-read', 'fantasy', 'owned', 'books-i-own',...       4.22            98
#
#   num_pages pub_year                                      similar_books  \
# 0         0   2001.0  ['8709549', '17074050', '28937', '158816', '22...
# 1       600   1987.0  ['19997', '828466', '1569323', '425389', '1176...
# 2       368   2009.0  ['6604176', '6054190', '2285777', '82641', '75...
# 3       162   2006.0                                                 []
# 4       216   2009.0  ['948696', '439885', '274955', '12978730', '37...
#
#                                                  url
# 0  https://www.goodreads.com/book/show/1333909.Go...
# 1  https://www.goodreads.com/book/show/7327624-th...
# 2  https://www.goodreads.com/book/show/6066819-be...
# 3  https://www.goodreads.com/book/show/287141.The...
# 4  https://www.goodreads.com/book/show/6066812-al...

# %%
# We check to see if all NAN are imputed
data_imputed_df[data_imputed_df['title']=='Second Glance']
# Out:
#          book_id author_id       authors          title  \
# 350       820228      7128  Jodi Picoult  Second Glance
# 351       820229      7128  Jodi Picoult  Second Glance
# 356       820227      7128  Jodi Picoult  Second Glance
# 113311   6397205      7128  Jodi Picoult  Second Glance
# 175578     10911      7128  Jodi Picoult  Second Glance
# 451391   2355102      7128  Jodi Picoult  Second Glance
# 512842  11214862      7128  Jodi Picoult  Second Glance
# 630403    526465      7128  Jodi Picoult  Second Glance
# 665498   3104040      7128  Jodi Picoult  Second Glance
#
#                                               description  \
# 350     Ross, a suicidal drifter and ghost hunter, is ...
# 351     From the moment Ross's fiancee Aimee was kille...
# 356     From the moment Ross's fiancee Aimee was kille...
# 113311  From the moment Ross's fiancee Aimee was kille...
# 175578  When odd, supernatural events plague the town ...
# 451391  - From the New York Times best-selling author ...
# 512842  From the moment Ross's fiancee Aimee was kille...
# 630403  "Sometimes I wonder....Can a ghost find you, i...
# 665498  "Sometimes I wonder....Can a ghost find you, i...
#
#                                           publisher  \
# 350     Createspace Independent Publishing Platform
# 351     Createspace Independent Publishing Platform
# 356                                          Hodder
# 113311                                  Atria Books
# 175578  Createspace Independent Publishing Platform
# 451391                               Recorded Books
# 512842  Createspace Independent Publishing Platform
# 630403                                  Atria Books
# 665498                      Washington Square Press
#
#                                                    genres avg_rating  \
# 350     ['to-read', 'currently-reading', 'fiction', 'j...       3.79
# 351     ['to-read', 'currently-reading', 'fiction', 'j...       3.79
# 356     ['to-read', 'currently-reading', 'fiction', 'j...       3.79
# 113311  ['to-read', 'currently-reading', 'fiction', 'j...       3.79
# 175578  ['to-read', 'currently-reading', 'fiction', 'j...       3.79
# 451391  ['to-read', 'currently-reading', 'fiction', 'j...       3.79
# 512842  ['to-read', 'currently-reading', 'fiction', 'j...       3.79
# 630403  ['to-read', 'currently-reading', 'fiction', 'j...       3.79
# 665498  ['to-read', 'currently-reading', 'fiction', 'j...       3.79
#
#        ratings_count num_pages pub_year  \
# 350               70         0   2006.0
# 351               82         0   2014.0
# 356               24       420   2007.0
# 113311          1200       494   2003.0
# 175578         33808         0   2014.0
# 451391            22         0   2008.0
# 512842            32         0   2014.0
# 630403           157       432   2003.0
# 665498           928       420   2008.0
#
#                                             similar_books  \
# 350     ['8359929', '723742', '297130', '7570244', '39...
# 351     ['8359929', '723742', '297130', '7570244', '39...
# 356     ['8359929', '723742', '297130', '7570244', '39...
# 113311  ['8359929', '723742', '297130', '7570244', '39...
# 175578  ['8359929', '723742', '297130', '7570244', '39...
# 451391  ['8359929', '723742', '297130', '7570244', '39...
# 512842  ['8359929', '723742', '297130', '7570244', '39...
# 630403  ['8359929', '723742', '297130', '7570244', '39...
# 665498  ['8359929', '723742', '297130', '7570244', '39...
#
#                                                       url
# 350     https://www.goodreads.com/book/show/820228.Sec...
# 351     https://www.goodreads.com/book/show/820229.Sec...
# 356     https://www.goodreads.com/book/show/820227.Sec...
# 113311  https://www.goodreads.com/book/show/6397205-se...
# 175578  https://www.goodreads.com/book/show/10911.Seco...
# 451391  https://www.goodreads.com/book/show/2355102.Se...
# 512842  https://www.goodreads.com/book/show/11214862-s...
# 630403  https://www.goodreads.com/book/show/526465.Sec...
# 665498  https://www.goodreads.com/book/show/3104040-se...

# %%
# sort the dataset by ratings_count in descending order
data_sorted = data_imputed_df.sort_values('ratings_count', ascending=False)

# drop duplicates based on author and title, and keep the first occurence (which has the highest ratings_count)
data_unique = data_sorted.drop_duplicates(subset=['authors', 'title'], keep='first')

# print the first 5 rows of the unique dataframe
print(data_unique.head())
# Out:
#          book_id author_id              authors  \
# 242287   2767052    153394      Suzanne Collins
# 748769         3   1077326         J.K. Rowling
# 673991      2657      1825           Harper Lee
# 394846      4671      3190  F. Scott Fitzgerald
# 933517  11870085   1406384           John Green
#
#                                                     title  \
# 242287            The Hunger Games (The Hunger Games, #1)
# 748769  Harry Potter and the Sorcerer's Stone (Harry P...
# 673991                              To Kill a Mockingbird
# 394846                                   The Great Gatsby
# 933517                             The Fault in Our Stars
#
#                                               description  \
# 242287  Winning will make you famous.\nLosing means ce...
# 748769  Harry Potter's life is miserable. His parents ...
# 673991  The unforgettable novel of a childhood in a sl...
# 394846  THE GREAT GATSBY, F. Scott Fitzgerald's third ...
# 933517  There is an alternate cover edition .\n"I fel...
#
#                                publisher  \
# 242287                  Scholastic Press
# 748769                    Scholastic Inc
# 673991  Harper Perennial Modern Classics
# 394846                          Scribner
# 933517                      Dutton Books
#
#                                                    genres avg_rating  \
# 242287  ['favorites', 'currently-reading', 'to-read', ...       4.34
# 748769  ['to-read', 'favorites', 'fantasy', 'young-adu...       4.45
# 673991  ['to-read', 'favorites', 'classics', 'classic'...       4.26
# 394846  ['to-read', 'classics', 'favorites', 'fiction'...       3.89
# 933517  ['to-read', 'favorites', 'young-adult', 'ficti...       4.26
#
#        ratings_count num_pages pub_year  \
# 242287       4899965       374   2008.0
# 748769       4765497       320   1997.0
# 673991       3255518       324   2006.0
# 394846       2758812       180   2004.0
# 933517       2429317       313   2012.0
#
#                                             similar_books  \
# 242287  ['1902241', '146499', '954674', '9917938', '10...
# 748769  ['13830', '127586', '121822', '37586', '616435...
# 673991  ['1934', '2156', '15638', '53835', '77142', '5...
# 394846  ['48203', '337113', '176972', '188087', '10956...
# 933517  ['10051706', '11418182', '10327303', '9627755'...
#
#                                                       url
# 242287  https://www.goodreads.com/book/show/2767052-th...
# 748769  https://www.goodreads.com/book/show/3.Harry_Po...
# 673991  https://www.goodreads.com/book/show/2657.To_Ki...
# 394846  https://www.goodreads.com/book/show/4671.The_G...
# 933517  https://www.goodreads.com/book/show/11870085-t...

# %%
data_unique[data_unique['title']=='Second Glance']
# Out:
#        book_id author_id       authors          title  \
# 175578   10911      7128  Jodi Picoult  Second Glance
#
#                                               description  \
# 175578  When odd, supernatural events plague the town ...
#
#                                           publisher  \
# 175578  Createspace Independent Publishing Platform
#
#                                                    genres avg_rating  \
# 175578  ['to-read', 'currently-reading', 'fiction', 'j...       3.79
#
#        ratings_count num_pages pub_year  \
# 175578         33808         0   2014.0
#
#                                             similar_books  \
# 175578  ['8359929', '723742', '297130', '7570244', '39...
#
#                                                       url
# 175578  https://www.goodreads.com/book/show/10911.Seco...

# %% [markdown]
# # We have successfully removed all the duplicates based on author and title and only kept the one with the highest rating counts.

# %% [markdown]
# ### Genres

# %%
data_unique[data_unique['authors']== 'Jodi Picoult']
# Out:
#           book_id author_id       authors                       title  \
# 175575      10917      7128  Jodi Picoult          My Sister's Keeper
# 1030252     14866      7128  Jodi Picoult            Nineteen Minutes
# 914495      14864      7128  Jodi Picoult                 Plain Truth
# 156983   15753740      7128  Jodi Picoult             The Storyteller
# 1024817     10909      7128  Jodi Picoult            The Tenth Circle
# ...           ...       ...           ...                         ...
# 361403   28820307      7128  Jodi Picoult               A l'intérieur
# 988419    1021437      7128  Jodi Picoult      Die Macht Des Zweifels
# 576868   34773147      7128  Jodi Picoult  La Tristesse des éléphants
# 10581    28189591      7128  Jodi Picoult        Harvesting The Heart
# 122157    6438214      7128  Jodi Picoult            Handle With Care
#
#                                                description  \
# 175575   Anna is not sick, but she might as well be. By...
# 1030252  In nineteen minutes, you can mow the front law...
# 914495   The small town of Paradise, Pennsylvania, is a...
# 156983   Sage Singer befriends an old man who's particu...
# 1024817  Fourteen-year-old Trixie Stone is in love for ...
# ...                                                    ...
# 361403   Quand votre fils ne vous regarde jamais dans l...
# 988419   In the course of her everyday work, career-dri...
# 576868   La mere de Jenna, Alice, a disparu lorsque cel...
# 10581    A young woman who was abandoned by her mother ...
# 122157   When Willow is born with severe osteogenesis i...
#
#                                            publisher  \
# 175575                       Washington Square Press
# 1030252                                  Atria Books
# 914495                                   Atria Books
# 156983                                         Atria
# 1024817                                Allen & Ulwin
# ...                                              ...
# 361403   Createspace Independent Publishing Platform
# 988419   Createspace Independent Publishing Platform
# 576868   Createspace Independent Publishing Platform
# 10581                                  Allen & Unwin
# 122157                           Atria International
#
#                                                     genres avg_rating  \
# 175575   ['to-read', 'fiction', 'currently-reading', 'f...       4.06
# 1030252  ['currently-reading', 'fiction', 'to-read', 'c...        4.1
# 914495   ['to-read', 'currently-reading', 'fiction', 'b...       3.97
# 156983   ['to-read', 'currently-reading', 'fiction', 'f...       4.26
# 1024817  ['to-read', 'fiction', 'jodi-picoult', 'books-...       3.48
# ...                                                    ...        ...
# 361403   ['currently-reading', 'jodi-picoult', 'favorit...       4.01
# 988419   ['to-read', 'currently-reading', 'books-i-own'...       3.93
# 576868   ['to-read', 'currently-reading', 'fiction', 'f...       3.94
# 10581    ['to-read', 'jodi-picoult', 'currently-reading...       3.59
# 122157   ['to-read', 'currently-reading', 'fiction', 'j...       3.96
#
#         ratings_count num_pages pub_year  \
# 175575         876319       423   2005.0
# 1030252        239763       440   2007.0
# 914495         129447       405   2004.0
# 156983         111927       460   2013.0
# 1024817        100103       416   2006.0
# ...               ...       ...      ...
# 361403             11         0   2014.0
# 988419             10         0   2014.0
# 576868             10         0   2014.0
# 10581               9       453   2009.0
# 122157              8       477   2009.0
#
#                                              similar_books  \
# 175575   ['1472878', '5161', '8492768', '5166', '760226...
# 1030252  ['217433', '6251052', '5355136', '228128', '91...
# 914495   ['161084', '1268348', '297134', '781910', '637...
# 156983   ['14759321', '15793165', '17125479', '2485785'...
# 1024817  ['6081394', '3975186', '15850', '8359929', '14...
# ...                                                    ...
# 361403   ['2589061', '1470232', '6335026', '4071018', '...
# 988419   ['895617', '8359929', '1152201', '14959', '147...
# 576868   ['827361', '18371384', '18722887', '18144049',...
# 10581    ['8359929', '297130', '895617', '64694', '3323...
# 122157   ['6251052', '2564278', '8359929', '3121162', '...
#
#                                                        url
# 175575   https://www.goodreads.com/book/show/10917.My_S...
# 1030252  https://www.goodreads.com/book/show/14866.Nine...
# 914495   https://www.goodreads.com/book/show/14864.Plai...
# 156983   https://www.goodreads.com/book/show/15753740-t...
# 1024817  https://www.goodreads.com/book/show/10909.The_...
# ...                                                    ...
# 361403   https://www.goodreads.com/book/show/28820307-a...
# 988419   https://www.goodreads.com/book/show/1021437.Di...
# 576868   https://www.goodreads.com/book/show/34773147-l...
# 10581    https://www.goodreads.com/book/show/28189591-h...
# 122157   https://www.goodreads.com/book/show/6438214-ha...
#
# [63 rows x 13 columns]

# %%
data_unique.to_csv('Removed_Duplicats_df.csv', index = False)

# %%
# !pwd
# Out:
# /kaggle/working

# %%
df = pd.read_csv('Removed_Duplicats_df.csv')

# %% [markdown]
# ## Cleaning the Genres Column

# %%
data_unique['genres'][175575]
# Out:
# "['to-read', 'fiction', 'currently-reading', 'favorites', 'books-i-own', 'jodi-picoult', 'chick-lit', 'book-club', 'contemporary', 'owned', 'drama', 'young-adult', 'adult', 'adult-fiction', 'realistic-fiction', 'contemporary-fiction', 'favourites', 'general-fiction', 'owned-books', 'family', 'novels', 'contempor\\u200bary', 'ya', 'made-me-cry', 'my-books', 'bookclub', 'tear-jerker', 'library', 'cancer', 'i-own', 'to-buy', 'default', 'rory-gilmore-reading-challenge', 'favorite-books', 'kindle', 'shelfari-favorites', 'all-time-favorites', 'sisters', 'novel', 'picoult', 'death', 'favorite', 'my-library', 'audiobook', 'book-club-books', 'sad', 'borrowed', 'movies', 'my-favorites', '5-stars', 'read-in-2009', 'tear-jerkers', 'audiobooks', 'romance', 'medical', 'movie', 'stand-alone', 'rory-gilmore-challenge', 'own-it', 'family-relationships', 'book-to-movie', 'coming-of-age', 'realistic', 'book-group', 'audio', 'wish-list', 'books', 'illness', 'relationships', 'literature', 'ebook', 'chicklit', 'literary-fiction', 'rory-gilmore', 'books-that-made-me-cry', 'finished', 'ebooks', 'read-in-2014', 'faves', 'have', 'modern-fiction', 'womens-fiction', 'recommended', 'english', '2005', 'death-and-dying', 'high-school', 'popular-fiction', 'book-club-reads', 'rory-gilmore-reading-list', 'read-in-2010', 'books-to-movies', 'women-s-fiction', 'thought-provoking', 'chic-lit', 'american', 'want-to-read', 'general', 'classics', 'tearjerker']"

# %%
data_unique[data_unique['book_id']== 10917]['genres']
# Out:
# 175575    ['to-read', 'fiction', 'currently-reading', 'f...
# Name: genres, dtype: object

# %%
#Remove space and make all text lower case.
data_unique['genres'] = data_unique['genres'].str.strip().str.lower()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Split the genres column into multiple columns
genres = data_unique['genres'].str.split(';', expand=True)

# %%
# Stack the columns into a single column and count the frequencies
genre_counts = genres.stack().value_counts()

# %%
# Get the top 5 genres
top_genres = genre_counts.head(10).index.tolist()

# %%
# Count the frequencies of each genre label
genre_counts = data_unique['genres'].explode().value_counts()

# Print the top 10 genres
print(genre_counts.head(10))
# Out:
# ['to-read']                                   2588
# ['to-read', 'currently-reading']              1451
# ['currently-reading', 'to-read']               362
# []                                             239
# ['to-read', 'poetry']                          164
# ['currently-reading']                           87
# ['to-read', 'favorites']                        78
# ['to-read', 'fiction']                          63
# ['to-read', 'poetry', 'currently-reading']      41
# ['to-read', 'kindle']                           41
# Name: genres, dtype: int64

# %%
print()
